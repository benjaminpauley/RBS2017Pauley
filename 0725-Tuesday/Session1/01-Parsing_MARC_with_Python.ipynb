# %% [markdown]
# # Parsing MARC records with Pymarc #
#
# In this exercise, we're going to use the Pymarc library to extract information from a file of library catalog records in MARC format.
#
# This code is meant to provide some practical techniques for dealing with MARC data. It's not necessarily the most elegant Python (experienced coders may well see better ways to accomplish these things), but each cell will introduce a different coding technique that is more broadly applicable (variables, control flow, conditionals, etc.). Likewise, professional catalogers may well see nuances of MARC that I'm passing over or missing.
#
# All of the code examples here target Python 2.7. Python 2.7 isn't the most recent current of Python, and the code would need some updating for compatibility with Python 3. But you'll find lots of tutorials and discussion board posts targeted at Python 2.7, so this code may provide a reasonable starting point for further learning.

# %% [markdown]
# ## Opening a file and reading it ##
#
# This first example handles the basic steps we'll need to perform to deal with a file of MARC records:
# * Importing the necessary library for reading MARC records (provided by the Pymarc package);
# * Opening our file of MARC records;
# * Passing the contents of the file to Pymarc's MARCReader function;
# * Initiating an operation on each record in the file.
#
# MARC is a long-lived format, and is actually quite ingenious--but it's also kind of abstruse and a bit cumbersome to work with in its raw form. Pymarc is a library that handles all the mucky business of reading MARC data for us and makes it available for use in our Python scripts. By "importing" Pymarc's MARCReader function, our script gets access to everything that Pymarc "knows" about reading MARC: Pymarc reads MARC so we don't have to.
#
# Refer to the "MARC Crash Course" handout for a quick overview of some of the MARC fields we're most likely to be interested in. For complete documentation, see https://www.loc.gov/marc/bibliographic/
#
# (In the cells below, you'll see that lines with an octothorpe [aka "pound sign" or "hashtag"] at the beginning appear in light green italics. Those lines are comments and not code that gets executed. I've used comments to provide, well, commentary on the code. But we can also "comment out" a line of code to prevent it from running. In some of the examples below, I've commented out some commands so that they won't execute when you run the code in the cell the first time, then asked you to "uncomment" the command and re-run the code to see what changes. To "comment out" a line of code, simply add an octothorpe at the beginning of the line. To "uncomment" a line, just delete the octothorpe from the beginning of the line.)

# %%
# Import the necessary components from the Pymarc library.
from pymarc import MARCReader

# This is a pretty standard way of working with a file in Python. We open the file by passing the filename
# to the open command and indicate that we want to open the file in "readable" mode. While we're at it, we
# create a variable name ("infile") to use as an alias for referring to our file. 

with open('data/Bowyer_from_ESTC-sample.mrc', 'r') as infile :
    # Note the colon at the end of the "with" statement, as well as the indentation of the subsequent code. 
    # White space matters in Python. The indented code is executed "inside" the statement
    # above it. (Other languages would use, say, curly braces, to indicate this sort of control flow.)
    
    # Next, we pass the contents of the file we just opened to the MARCReader function of the Pymarc library.
    # This will allow us to use all of the methods that that library offers for reading MARC data.
    reader = MARCReader(infile) 
    # We're going to want to do something with each of the records in our file, so we'll begin a "for" loop.
    # Just as we did for our "with" statement above, the for statement ends with a colon and the subsequent
    # code is indented. The code inside this loop will be run for each item that the loop encounters. 
    # (Note that the variable name "record" is arbitrary--we could use "x" or "imelda" and the computer would 
    # understand just fine. But we need our code to be human-readable, too, so let's stick with variable names
    #  that make sense to us.)
    for record in reader :
        # Let's just keep things simple at this point and print each record to prove that we really do have a 
        # set of MARC records to work with.
        print(record)
# Out:
# =LDR  01493nam a2200229   4500
# =001  N10049
# =003  CU-RivES\
# =005  20090206223027.0
# =008  840710s1758\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000111\
# =035  \\$a(Uk-ES)006000111
# =040  \\$aCU-RivES$cCU-RivES$dCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aDavila, Arrigo Caterino,$d1576-1631.
# =240  10$aIstoria delle guerre civilé di Francia.$lEnglish
# =245  14$aThe history of the civil wars of France.$bIn which are related, the most remarkable transactions that happened during the reigns of Francis the Second, Charles the Ninth, Henry the Third, and, Henry the Fourth, surnamed the Great. A new translation from the Italian of Henrico Caterino Davila. By Ellis Farneworth, M. A. ...
# =260  \\$aLondon :$bprinted for D. Browne, without Temple-Bar A. Millar, in the Strand J. Whiston and B. White, in Fleet-Street R. and J. Dodsley, in Pall-Mall and W. Sandby, in Fleet-Street,$cMDCCLVIII. [1758]
# =300  \\$a2v. ;$c4⁰.
# =533  \\$aMicrofilm.$bWoodbridge, Conn.:$cPrimary Source Media,$d1999.$e1 reel ; 35 mm.$f(The Eighteenth Century ; reel 10545, no. 02).$7s1999 ctu b
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =651  \0$aFrance$xHistory$yWars of the Huguenots, 1562-1598.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01693cam a2200289   4500
# =001  N10081
# =003  CU-RivES
# =005  20091118161529.0
# =008  840710s1728\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000146
# =035  \\$a(Uk-ES)006000146
# =040  \\$aCU-RivES$cCU-RivES$dCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aHolland, Richard,$d1688-1730.
# =245  10$aObservations on the small pox: or, An essay to discover a more effectual method of cure.$bBy Richard Holland, M.D. Fellow of the College of Physicians and the Royal Society.
# =260  \\$aLondon :$bprinted for John Brindley, Bookbinder to the Majesty, at the King's Arms in New-Bond-Street,$c1728.
# =300  \\$a[8],xix,[1],76,79-164[i.e.162]p. ;$c8⁰.
# =500  \\$aP.162 misnumbered 164; variant: p.162 correctly numbered.
# =500  \\$aText is continuous despite pagination.
# =500  \\$aSig.O3 (pp.83-84) and sig.Q4 (pp.101-102) are cancels; p.83 line 5 ends: "too"; p.101 line 14 ends: "the".
# =500  \\$aIn some copies, sigs. O3 and Q4 have not been cancelled; p.83 line 5 ends: "as"; p.101 line 14 ends: "strenghen".
# =500  \\$aPrinted by William Bowyer; his records show 350 ordinary and 150 large-paper copies printed.
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c1365
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1988.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 3073, no. 8).
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =650  \0$aSmallpox.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01208cam a2200289   4500
# =001  N101
# =003  CU-RivES\
# =005  20090516220242.0
# =008  820917s1733\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000166\
# =035  \\$a(Uk-ES)006000166
# =040  \\$aCU-RivES$cCU-RivES$dUk-ES$dCStRLIN
# =100  1\$aHasledine, William,$d1713 or 14-1773.
# =240  10$aBellus homo et academicus.$lEnglish
# =245  14$aThe beau and the academick.$bA dialogue in imitation of Bellus homo and academicus, spoken at the late publick act at Oxford. Address'd to the ladies.
# =260  \\$aLondon :$bprinted for J. Roberts,$c[1733]
# =300  \\$a[4],12p. ;$c4⁰.
# =500  \\$aPreface signed: Bellamant i.e. William Bowyer.
# =500  \\$aA translation of William Hasledine's 'Bellus homo et academicus', 1733.
# =500  \\$aPrinted by William Bowyer; his records show 500 copies printed for himself and Innys as partners.
# =500  \\$aSignatures: A² B⁴ C².
# =500  \\$aSignatures from Maslen & Lancaster, and Foxon.
# =510  4\$aFoxon,$cB337
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c1975
# =648  \7$a1701-1800$2local
# =700  1\$aBowyer, William,$d1699-1777.
# =752  \\$aGreat Britain$bEngland$dLondon.
#
# =LDR  01544nam a2200277   4500
# =001  N10263
# =003  CU-RivES
# =005  20060812125846.0
# =008  840716s1767\\\\enk||||\\\\\\\00||||eng\c
# =009  006000348
# =035  \\$a(Uk-ES)006000348
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aClarke, John,$d1687-1734.
# =245  12$aA new grammar of the Latin tongue, comprising all necessary for grammar-schools.$bTo which is annexed a dissertation upon language. By John Clarke, Author of the Two Essays upon Education and Study, Introduction to the Making of Latin, &c.
# =246  3\$aNew grammar of the Latin tongue, comprising all in the art necessary for grammar-schools
# =250  \\$aThe fifth edition, corrected.
# =260  \\$aLondon :$bprinted for L. Hawes, W. Clarke, and R. Collins, in Pater-Noster Row,$cM.DCC.LXVII. [1767]
# =300  \\$axv,[3],173,[1]p. ;$c12⁰.
# =509  \\$aThe leaf following that numbered xv on recto is numbered 18, 17
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1986.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1583, no. 04).
# =533  \\$aElectronic reproduction.$bFarmington Hills, Mich. :$cThomson Gale,$d2003.$f(Eighteenth century collections online).$nAvailable via the World Wide Web.$nAccess limited by licensing agreements.
# =648  \7$a1701-1800$2local
# =650  \0$aLatin language$xGrammar$vEarly works to 1800.
# =655  \7$aGrammars.$2rbgenr
# =752  \\$aGreat Britain$bEngland$dLondon.
# =985  \\$aSubject headings created by HTC$dMay 2008$inCU-RivES
#
# =LDR  01565cam a2200301   4500
# =001  N10280
# =003  CU-RivES\
# =005  20080503043207.0
# =008  840716s1710\\\\enk||||\\\\\\\00|\||eng\c
# =009  006000366\
# =035  \\$a(Uk-ES)006000366
# =040  \\$aCU-RivES$cCU-RivES$dCStRLIN$dCU-RivES
# =100  1\$aSpinckes, Nathaniel,$d1654-1727.
# =245  14$aThe new pretenders to prophecy re-examined:$band their pretences shewn to be groundless and false. And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture. By N. Spinckes a Presbyter of the Church of England.
# =260  \\$aLondon :$bprinted for Richard Sare, at Grays-Inn-Gate in Holbourn,$c1710.
# =300  \\$axvi,56p. ;$c8⁰.
# =500  \\$aOn A. Whitrow's 'The warnings of the eternal spirit' with preface by Sir Richard Bulkeley.
# =500  \\$aAnother issue omits "And Sir R. Bulkeley and A. Whitro convicted of very foul practices, in order to the carrying on their imposture." in title.
# =500  \\$aPrinted by William Bowyer.
# =500  \\$aSignatures: A-D⁸ E⁴.
# =500  \\$aSignatures from Maslen & Lancaster.
# =510  4\$aMaslen & Lancaster. Bowyer ledgers,$c24
# =533  \\$aMicrofilm.$bWoodbridge, CT$cResearch Publications, Inc.,$d1985.$e1 reel ; 35mm.$f(The Eighteenth Century ; reel 1273, no. 29).
# =600  10$aBulkeley, Richard,$cSir,$d1644-1710.
# =600  10$aWhitrow, Abraham.$tWarnings of the eternal spirit.
# =648  \7$a1701-1800$2local
# =650  \0$aProphets$zGreat Britain.
# =752  \\$aGreat Britain$bEngland$dLondon.

# %% [markdown]
# ## Accessing MARC fields with Pymarc ##
#
# There's not much point in using Python just to print formatted MARC records to the screen. We're probably more interested in the contents of the fields and subfields than we are with the MARC tags and subfield codes. This is where Pymarc's ability to interpret MARC for us comes into play: MARCReader allows us to access the contents of fields and subfields using a pretty straightforward syntax.
#
# (In the next few examples, we're going to stick to non-repeatable MARC fields. Repeatable fields need to be treated a little differently. We'll get there.)
#
# The next cell works through a couple of ways of accessing MARC data. Run the code in the cell, then comment out the first print command, uncomment the next ones and re-run the code. Repeat that process for the final set of print commands.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        # We can access the content of fields like this:
        #print(record['245'])
        
        # More helpful, though, is our ability to access the content of subfields:
        #print(record['245']['a'])
        #print(record['245']['b'] + '\n')
        
        # Not all MARC fields have subfields. To access the contents of these controlfields, use ".data"
        print(record['001'].data)
        print(record['008'].data + '\n')
# Out:
# N10049
# 840710s1758    enk||||       00| ||eng c
#
# N10081
# 840710s1728    enk||||       00| ||eng c
#
# N101
# 820917s1733    enk||||       00| ||eng c
#
# N10263
# 840716s1767    enk||||       00||||eng c
#
# N10280
# 840716s1710    enk||||       00| ||eng c

# %% [markdown]
# ### Variables ###
# Reading and printing the contents of MARC fields is all well and good, but we probably want to be able to hold on to that information and do something with it. That's much easier to do when we declare variables and assign values to them. For most people, something like "main_title" is easier to understand and remember than "record['245']['a']". It's certainly easier and faster type.
#
# In the cell below, I've created a variable to hold the value of MARC 245|a and then print that variable. After running the code, add your own variable to get the value of MARC 260|c, then uncomment the final print command and re-run the code in the cell.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        # Now we'll create some variables and assign them the values of selected fields from our MARC records.
        main_title = record['245']['a']
        
         # >> Create a new variable called "imprint_year" and assign it the value of MARC 260|c. Then uncomment
         # >> the print(imprint_year) command by deleting the octothorpe at the beginning of the line and run the
         # >> code in this cell.
        
        print(main_title)
        #print(imprint_year)
# Out:
# The history of the civil wars of France.
# Observations on the small pox: or, An essay to discover a more effectual method of cure.
# The beau and the academick.
# A new grammar of the Latin tongue, comprising all necessary for grammar-schools.
# The new pretenders to prophecy re-examined:

# %% [markdown]
# ### Conditionals ###
# While every MARC record has a title field (245), not all records have a main author field (100). Texts created by corporate authors, for example, have 110 fields, instead; works for which no author is known may not have any main author entry. If we were simply to create a variable for `author_name` and assign it the value of MARC 100|a, we'll run into an error when we come across a record that doesn't have a 100 field.
#
# In this next example, we'll check to see if the record *has* a 100 field before assigning the content of 100|a to a variable.

# %%
from pymarc import MARCReader
with open('data/Bowyer-from-ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        main_title = record['245']['a']
        # Check to see if the record has a 100 field. Python's syntax can seem a bit terse in comparison to 
        # some other languages, but we could think of this statement as saying something like "If there is a
        # 100 field..." As with other statements, note the colon at the end.
        if record['100'] :
            # The indented code will only be executed if the condition in the if statement is met. If there  
            # isn't a 100 field in the record, this code will be skipped.
            author_name = record['100']['a']
            print(author_name)
            print(main_title)
        # Now we can say what to do if our "if" condition *isn't* met. (In this small MARC sample, all of the
        # records have 100 fields, so we won't end up reaching this part of the loop in this example.)
        else :
            print('No author')
            print(main_title)

# %% [markdown]
# ## Data types and structures ##
#
# As with any language, Python can work with different types of data, including (among others): strings of characters; various kinds of numbers (integers, or whole numbers, and "floats"--numbers with decimals); "lists" (simple collections of data); and "dictionaries" (mapped collections of information with values corresponding to keys). For a discussion of Python's native data types, see: https://docs.python.org/3/library/stdtypes.html
#
# What follows is by no means an exhaustive tour of different data types, but just an introductory overview of some basics that you can start working with pretty quickly. The fact that we're working with MARC data means we need first to deal with strings: because a MARC record is simply a plaintext file, everything in it is actually a string of text, no matter what it looks like.

# %% [markdown]
# ### Manipulating strings ###
# If you take a look at the output of the last example, you'll see that the authors' names all end with commas and the titles all end with periods. That kind of punctuation is included in the MARC specification, which ensures that records are formatted correctly when they are displayed by a library's ILS. Depending on what we were doing, we might want to get rid of those commas.
#
# Python gives us lots of ways to manipulate strings. This is far too big a topic to cover in much depth here (documentation for Python's native string methods is available here: https://docs.python.org/2/library/stdtypes.html#string-methods), but there are a few things we can do pretty quickly.
#
# In the next few examples, we'll dispense with reading the MARC file and just work with an author's name we already know about from our sample.

# %% [markdown]
# #### Stripping ####
# There are several ways to clean up white space and text at the beginnings and ends of strings. The `strip` command cleans up unwanted characters from both the beginnings and ends of strings, while the `lstrip` and `rstrip` remove unwanted characters from the left and right ends of a string, respectively. By default, all of these commands remove white spaces, but we can indicate the characters we want to remove, instead.

# %%
## Stripping

## For the sake of convenience, we'll just set the variable of author_name to a string.
author_name = "Davila, Arrigo Caterino,"

## Let's get rid of that trailing comma by using "rstrip" to remove a defined character (the comma) from the right
## end of the string. 

author_name_stripped = author_name.rstrip(',')
print(author_name_stripped)
# Out:
# Davila, Arrigo Caterino

# %% [markdown]
# #### Partitioning ####
# There are plenty of times when we might want to split a string of text whenever we encounter a certain separator character. The `partition` command is a little more esoteric, but can come in handy. Given a string and a separator character, `partition` returns three pieces of information: the portion of the string before the separator, the separator itself, and the portion of the string after the separator. These three pieces of information are stored as a list (a data type we'll look at more in a little bit), and can be retrieved by referring to their position in the list. In Python, as in many other languages, we begin counting at zero rather than one (which can be tricky to remember at first).

# %%
# Partitioning

# If we partition author_name_stripped on the comma, we'll be able to rearrange the author's name in firstname 
# middlename lastname order by putting the third part of our partition before the first part. Keep in mind that, in 
# Python as with many other languages, we begin counting at 0 rather than at 1.

name_parts = author_name_stripped.partition(', ')
print name_parts[2] + ' ' + name_parts[0]
# Out:
# Arrigo Caterino Davila

# %% [markdown]
# #### Substrings ####
# Sometimes we want to extract just a portion of a longer string. There are several different ways to do this, but the simplest case would be one where we know that we're looking for a substring of a certain length occurring at a certain known position in a longer string.
#
# Let's consider the MARC 008 control field, which is a fixed-length field that reports structured information about the record, with different character positions reserved for different pieces of information. Characters 7-10 (and, in some cases, 11-14) provide regularized publication dates for the title described by the record. Those dates can mean different things, depending on the record (the nature of the dates is reported in character 6), but for this example we can overlook those nuances and say that characters 7-10 represent the publication date.
#
# In the example below, we get the contents of the MARC 008 field by using the .data syntax, and then specify the portion of that string we want: `[7:11]`. This seems strange. If we want characters 7-10, why 11? What's happening here is that our result begins the character at our starting index position and goes up to *but not including* the character at our ending position.
#
# (It's worth pointing out here that a lot of this syntax will come up again when we begin working with lists. That's because, in a sense, a string is really just a list of characters.)

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        pub_year = record['008'].data[7:11]
        print(pub_year)

# %% [markdown]
# Let's look at a couple of other substring examples. Most of these will seem a little arbitrary, but there may be times when we'd need them. Comment and uncomment the various print commands in the cell below to see what they do.

# %%
# For this example, we'll forego reading the MARC file and just work with some static strings.
main_title = 'Observations on the small pox: or, An essay to discover a more effectual method of cure.'
author_name = 'Holland, Richard,'

# Retrieve the first 20 characters of the title (this is the same as saying [0:21])
print(main_title[:21])

# Retrieve the last 20 characters of the title (start at the 20th character from the end and continue to 
# the end of the string).
#print(main_title[-21:])

# We can combine string operations to do more obviously sensible things, like getting the portion of the
# title up to the colon...
#print(main_title[0:main_title.find(':')])

# ... or the author's last name, by getting the portion up to the comma...
#print(author_name[0:author_name.find(',')])

# ... or the author's first name, by getting the portion after the first comma and white space, and up to the 
# last comma. (Though, really, partition(',') would be easier for this.):
#print(author_name[author_name.find(', ')+2:author_name.rfind(',')])

# %% [markdown]
# #### Converting strings to numbers ####
# In an earlier example, we extracted four characters from the 008 control field to get a regularized publication year. But, crucially, while those are numerical characters, as far as the computer is concerned, they don't represent a number. Run the code in the cell below and study the error message that we get when we try to calculate how long ago a book was published by subtracting the publication date from the current year.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        pub_year = record['008'].data[7:11]
        print(pub_year)
        years_ago = 2017 - pub_year
        print(years_ago)

# %% [markdown]
# It turns out, you can't subtract a string from an integer. (In this case, we're dealing with a unicode string, since our file of MARC records is encoded as UTF-8.) Despite what it looks like to us, the value of `pub_year`--"1758"--isn't something that our script can recognize as a number. We can confirm the problem by inspecting the datatype of `pub_year`.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        pub_year = record['008'].data[7:11]
        print(pub_year)
        print(type(pub_year))
# Out:
# 1758
# <type 'unicode'>
# 1728
# <type 'unicode'>
# 1733
# <type 'unicode'>
# 1767
# <type 'unicode'>
# 1710
# <type 'unicode'>

# %% [markdown]
# If we want to use the string of characters we extracted from the 008 control field as a year that we can use in calculations, we need to convert it from a unicode string to an integer. (Note, though that, in the last line, I've had to convert that integer *back to a string* in order to combine it with the words " years ago."!)

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        pub_year = record['008'].data[7:11]
        print(pub_year)
        years_ago = 2017 - int(pub_year)
        print(str(years_ago) + ' years ago.')
# Out:
# 1758
# 259 years ago.
# 1728
# 289 years ago.
# 1733
# 284 years ago.
# 1767
# 250 years ago.
# 1710
# 307 years ago.

# %% [markdown]
# #### Concatenating strings ####
# There's probably lots more you could find yourself needing to do with strings, but my hope is that these examples will give you enough of a starting point to figure out the syntax explained in Python documentation or that you find online. That last example, though, does provide an occasion to talk about concatenating--i.e., chaining together--strings. In Python, this is done by simply using plus signs.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    for record in reader :
        author_name = record['100']['a'].rstrip(',')
        main_title = record['245']['a']
        pub_city = record['260']['a'].rstrip(' :')
        imprint = record['260']['b']
        pub_year = record['008'].data[7:11]
        print(author_name + '. ' + main_title + ' (' + pub_city  +': ' + imprint + ' ' + pub_year + '.)')

# %% [markdown]
# ### Working with lists ###
#
# We've already gotten a bit of a preview of working with lists from some of our work with substrings, but let's take a closer look. In the next example, we'll create a list to hold the names of the authors for our records and add the authors' names to that list as we iterate through the MARC records in the file.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    # Create a variable named "authors" that is an empty list. Note that this variable is created *outside* our for
    # loop...
    authors = []
    for record in reader :
        author_name = record['100']['a'].rstrip(',')
        # Now append each author_name to our list of authors.
        authors.append(author_name)
    # Note that we've left the "for" loop. In our earlier examples, the values of our variables were only available
    # inside the for loop--this time, we collected the values as we looped through the MARC records and stored
    # them in a list where we can get to them even again.
    print(authors)

# %% [markdown]
# We access the individual items in the list by using their index numbers (this should look familiar from our substring examples). Note that can also check to see how many items are in a list using `len()`. Comment and uncomment the print commands below to se how different list indices work

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    authors = []
    for record in reader :
        author_name = record['100']['a'].rstrip(',')
        authors.append(author_name)
    print(authors)
    print(len(authors))
    #print(authors[1])
    #print(authors[0])
    #print(authors[-1])
    #print(authors[0:3])
    #print(authors[0:-2])
    #print(authors[:2])
    #print(authors[3:])

# %% [markdown]
# We can iterate through the items in a list in the same way we've been iterating through the MARC records in our file.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-sample.mrc','r') as infile :
    reader = MARCReader(infile)
    authors = []
    for record in reader :
        author_name = record['100']['a'].rstrip(',')
        authors.append(author_name)
    # Note that "author" is an arbitrary name. We could say "for i in authors" and it would work just as well
    for author in authors :
        print(author)

# %% [markdown]
# In our examples so far, we've been working with a very small sample set of just five MARC records, and those records all happen to be for titles written by different authors. If we were to work with a larger set of MARC records (as in this next example), we could expect to encounter multiple records with the same author. If we were to add all of the authors to our list as we've been doing so far, we'd end up with duplicates in our list. In some scenarios, that might not be a problem, but we could use an `if` statement to check and make sure that our `author_name` isn't already in the list before adding it. (While we're at it, let's add in a check to make sure that there's actualy a 100 field in the record before we try to get a nonexistent 100|a subfield.)

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-full.mrc','r') as infile :
    reader = MARCReader(infile)
    authors = []
    for record in reader :
        if record['100'] :
            author_name = record['100']['a'].rstrip(',')
            if author_name not in authors :
                authors.append(author_name)
    print(len(authors))
    for author in authors :
        print author
    # If we wanted to, we could put sort the list alphabetically:
    #authors.sort()
    #for author in authors :
        #print author

# %% [markdown]
# ### Working with dictionaries ###
#
# While lists are useful for some kinds of work, other situations call for a different kind of data structure. A dictionary holds data as a series of key/value pairs. Note that the values of a dictionary can be any combination of strings, numbers, lists, and even other dictionaries, so a dictionary can represent very complex information (and can get correspondingly complex to deal with in a hurry!).
#
# We could imagine holding data about a person in a dictionary like this, for example:
#
# `{'first_name': 'John', 'last_name': 'Doe', 'age': 73, 'hobbies': ['birding','stamp collecting','freestyle polka'], 'family_members': {'father': 'James Doe', 'mother': 'Mary Doe', 'sister': 'Ann Doe'}, 'eye_color': 'brown'}`
#
# In the next example, we'll create a dictionary rather than a list. We'll store authors' names as keys and keep a running count of the number of records by each author as the value. Because we don't know in advance what author names we might encounter, we'll use the `setdefault` command to add new keys to our dictionary if they aren't already present.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-full.mrc','r') as infile :
    reader = MARCReader(infile)
    # Create the variable authors, this time as an empty dictionary, rather than an empty list. (Note the 
    # curly braces in place of the square brackets we used in our earlier example.)
    authors = {}
    for record in reader :
        if record['100'] :
            author_name = record['100']['a'].rstrip(',')
            # We use setdefault: if author_name is not already present as a key in our dictionary, we'll
            # add a new key,value pair with the author_name as the key and 0 as the value.
            authors.setdefault(author_name,0)
            # Now we increment the value associated with the key for this author_name. If that wasn't already
            # present, we just created it with value 0, so we'll be making the value equal one. If that key
            # *was* already present, the setdefault comand won't have done anything, so we'll be adding one
            # to the value that was there (e.g., increasing 1 to 2, 12 to 13, etc.)
            authors[author_name] += 1
    for author in authors.items() :
        print(author)
# Out:
# (u'Pagett, Thomas Catesby', 5)
# (u'Nelson, Robert', 37)
# (u'Gerard, Alexander', 1)
# (u'Mauger, Claude.', 1)
# (u'Gordon, Robert', 1)
# (u'Whitefield, George', 24)
# (u'Xenophon.', 3)
# (u'Halket, Peter', 1)
# (u'Wynne, William', 1)
# (u'Underhill, Edward', 1)
# (u'Foord, Ellen', 1)
# (u'Drelincourt, Charles', 4)
# (u'Kinnoull, George Hay', 2)
# (u'Buckingham, John Sheffield', 2)
# (u'Crowne', 1)
# (u'Temple, William', 2)
# (u'Fitz-Adam, Adam.', 1)
# (u'Loughton, William.', 4)
# (u'Awbrey, Timothy', 2)
# (u'Craigengelt, Charles.', 1)
# (u'White, John', 22)
# (u'Mosheim, Johann Lorenz', 3)
# (u'Homer.', 13)
# (u'Florus, Lucius Annaeus.', 2)
# (u'Solleysel, Jacques de', 1)
# (u'Lobb, Theophilus', 2)
# (u'Pococke, Richard', 2)
# (u'Dunbar, Archibald.', 1)
# (u'Langford', 2)
# (u'Devonshire, William Cavendish', 1)
# (u'Ribadeneyra, Pedro de', 1)
# (u'Burke, William', 1)
# (u'Burton, Thomas', 1)
# (u'Ra\u0304zi\u0304, Abu\u0304 Bakr Muh\u0307ammad ibn Zakari\u0304ya', 1)
# (u'Harris, Walter', 3)
# (u'Morando, Bernardo', 2)
# (u'Roper, William', 1)
# (u'Gisbert, Blaise', 1)
# (u'Stirling, James', 2)
# (u'Pre\u0301vost', 4)
# (u'Ballard, Thomas', 2)
# (u'Blackburne, Francis', 6)
# (u'Drake, Francis', 2)
# (u'Toup, Jonathan', 2)
# (u'Mainwaring, John', 1)
# (u'La Vallie\u0300re, Franc\u0327oise-Louise de La Baume Le Blanc', 1)
# (u'Rousseau, Jean-Jacques', 1)
# (u'Pineda, Pedro.', 2)
# (u'Henry', 1)
# (u'Anstruther, Philip', 1)
# (u'Roccaforte, Gaetano.', 1)
# (u'Bale, John', 1)
# (u'Dunn, Samuel', 1)
# (u'Ashton, Thomas', 3)
# (u'Carpzov, Johann Gottlob', 1)
# (u'Gordon, John', 1)
# (u'Juvenal.', 3)
# (u'Loudoun, Hugh Campbell', 1)
# (u'Hall, Fayrer.', 7)
# (u'Goodman, John', 2)
# (u'Rushworth, John', 2)
# (u'Dufresnoy, Charles-Alphonse', 2)
# (u'Secundus, Johannes', 1)
# (u'Cantrell, Henry', 1)
# (u'Martin, David', 7)
# (u'Falconer of Halkertoun, David Falconer', 2)
# (u'Shuckburgh-Evelyn, George Augustus William', 1)
# (u'Newcome, John', 2)
# (u'Poole, James', 1)
# (u'Breval, John', 1)
# (u'Wilson, Benjamin', 4)
# (u'Blackall, Offspring', 3)
# (u'Clarke, John', 1)
# (u'Dionysius', 4)
# (u'Whitby, Daniel', 3)
# (u'Pindar.', 3)
# (u'Bignon, Jean Paul', 2)
# (u'King, William', 13)
# (u'Atterbury, Francis', 11)
# (u'Herodian.', 1)
# (u'Brodrick, Thomas.', 1)
# (u'Rundle, Thomas', 1)
# (u'Bond, Denis', 2)
# (u'Laurence, John', 3)
# (u'Gilles, Pierre', 1)
# (u'Broughton, John', 3)
# (u'Fielding, Henry', 6)
# (u'Munro, Alexander.', 1)
# (u'Ashmole, Elias', 1)
# (u'Scot, Walter', 1)
# (u'Charlevoix, Pierre-Franc\u0327ois-Xavier de', 1)
# (u'Cibber, Colley', 3)
# (u'Le Courayer, Pierre Franc\u0327ois', 1)
# (u'Monoux, Lewis', 1)
# (u'Powell, W. S.', 6)
# (u'Ayloffe, Joseph', 1)
# (u'Wood, Thomas', 5)
# (u'Dun, David Erskine', 2)
# (u'Townley, James', 2)
# (u'Meres, John', 1)
# (u'Moss, Robert', 4)
# (u'Heath, Thomas', 1)
# (u'Conway, Henry Seymour', 4)
# (u'Mossom, Robert', 1)
# (u'Sheridan, Thomas', 2)
# (u'Johnson, John', 1)
# (u'Richmond, Henry', 1)
# (u'Richardson, Jonathan', 6)
# (u'Nisbet, Janet.', 1)
# (u'Wing, Richard.', 1)
# (u'Rollin, Charles', 2)
# (u'Salmon, N.', 2)
# (u'Mulgrave, Constantine John Phipps', 1)
# (u'Milward, Edward', 1)
# (u'Anderson, Henry', 1)
# (u'Macpherson, James', 1)
# (u'Kingston, Evelyn Pierrepont', 1)
# (u'Astle, Thomas', 1)
# (u'Santa Cruz de Marcenado, Alvaro Navia Osorio', 1)
# (u'Shorey, William', 1)
# (u'Baynes, Walter.', 1)
# (u'Silence, Samuel.', 1)
# (u'Surman, Robert', 1)
# (u'Blantyre, Robert Stuart', 1)
# (u'Buchan, Charles.', 1)
# (u'Orosius, Paulus.', 1)
# (u'Swinden, Tobias', 1)
# (u'Lloyd, William', 1)
# (u'Madox, Thomas', 4)
# (u'Hardy, Richard', 1)
# (u'A** C**', 1)
# (u'Scott, John', 5)
# (u'Rutherforth, T.', 1)
# (u'Petyt, William', 1)
# (u'Pore\u0301e, Charles', 1)
# (u'Kerr, Christiana.', 2)
# (u'Beveridge, William', 3)
# (u'La Motte', 1)
# (u'Linne\u0301, Carl von', 1)
# (u'Mason, William', 4)
# (u'Jones, Robert', 1)
# (u'Smedley, Jonathan', 1)
# (u'Lowth, Robert', 16)
# (u'Bailey, John', 1)
# (u'Cunningham, James', 1)
# (u'Pluche, Noe\u0308l Antoine', 14)
# (u'North, Roger', 3)
# (u'Taylor, Jeremy', 3)
# (u'Walpole, Horace', 1)
# (u'Trotter, Catharine', 2)
# (u'Thompson, George', 1)
# (u'Goodall, W.', 1)
# (u'Sherlock, Thomas', 14)
# (u'Dugdale, William', 1)
# (u'Symson, Matthias', 1)
# (u'Regnault', 1)
# (u'Ancell, James', 1)
# (u'Milles, Jeremiah', 1)
# (u'Falconet, Etienne', 1)
# (u'Brokesby, Francis', 2)
# (u'Semple, Grissel.', 1)
# (u'Sophocles.', 3)
# (u'Physician in town.', 1)
# (u'Plukenet, Leonard', 1)
# (u'Sandilands, Isabell.', 1)
# (u'Du Port, Franc\u0327ois', 1)
# (u'Stillingfleet, Benjamin', 1)
# (u'Worthington, William', 3)
# (u'Holinshed, Raphael', 2)
# (u'Sievwright, Norman.', 1)
# (u'Keill, John', 1)
# (u'La Fontaine, Jean de', 1)
# (u'Weber, Friedrich Christian.', 1)
# (u'Cobden, Edward', 3)
# (u'Boerhaave, Herman', 2)
# (u'Barker, Samuel', 1)
# (u'Plutarch.', 2)
# (u'Short, Thomas', 2)
# (u'Baker, William', 1)
# (u'Smith, David', 1)
# (u'Bell, George', 4)
# (u'Richardson, Samuel', 3)
# (u'Farquhar, George', 13)
# (u'Eyles, John', 1)
# (u'Lockhart, George', 1)
# (u'S. L.', 2)
# (u'Fife, Gilbert.', 1)
# (u'Davies, Roger', 2)
# (u'Abdy, Stotherd', 1)
# (u'Martin, Samuel', 1)
# (u'Banks, John', 1)
# (u'Wilkinson, Richard', 1)
# (u'Cockburn, W.', 2)
# (u'Castleton, Nathaniel.', 4)
# (u'Smith, Roger', 1)
# (u'Browne, Isaac Hawkins', 1)
# (u'Frowde, Philip', 1)
# (u'Graves, Richard', 2)
# (u'Robertson, Thomas', 1)
# (u'Grigg, J.', 1)
# (u'Warburton, William', 28)
# (u'Lambarde, William', 1)
# (u'Moss, Charles', 1)
# (u'Ogilvie, Archibald.', 1)
# (u'Newton, James', 2)
# (u'Nevile, Thomas', 3)
# (u'Elstob, Elizabeth', 2)
# (u'Machiavelli, Niccolo\u0300', 2)
# (u'Tanner, Thomas', 2)
# (u'Drake, Samuel', 1)
# (u'Hoole, Joseph', 1)
# (u'Walker, Hovenden', 1)
# (u'Waterhouse, D.', 1)
# (u'Sewell, George', 1)
# (u'Manningham, Thomas', 2)
# (u'Hamilton, Anthony', 1)
# (u'Lyons, Israel', 2)
# (u'Tomlinson, Kellom.', 1)
# (u'Burroughs, Jeremiah', 1)
# (u'Lee, Nathaniel', 1)
# (u'Masters, Robert', 1)
# (u'Dene, Humphry.', 1)
# (u'Ward, Thomas', 1)
# (u'Cole, Thomas', 1)
# (u'Smith, John', 1)
# (u'Labat', 1)
# (u'Annandale, James Johnston', 1)
# (u'Pilkington, Matthew', 2)
# (u'Girard, Jean-Baptiste', 1)
# (u'Muller, John', 2)
# (u'Lodge, John', 1)
# (u'Byrom, John', 1)
# (u'Vernon, Edward', 2)
# (u'Drummond, James', 1)
# (u'Michaelis, Johann David', 1)
# (u'Fry, John', 1)
# (u'Saunderson, Nicholas', 4)
# (u'Millner, John.', 1)
# (u'Potter, R.', 2)
# (u'Schaw, John', 2)
# (u'Vertot', 1)
# (u'Macfarlane, George.', 1)
# (u'Lover of his country.', 1)
# (u'Stockdale, Percival', 1)
# (u'Freind, William', 1)
# (u'Bedford, Hilkiah', 4)
# (u'Tham, Volrath.', 1)
# (u'Knight, Richard', 1)
# (u'Fleet, Edward', 1)
# (u'Budgell, Eustace', 1)
# (u'Southerne, Thomas', 1)
# (u'Moore, Francis', 2)
# (u'Baker, Henry', 1)
# (u'Squire, Francis', 2)
# (u'Worthington, John', 1)
# (u'Tucker, Josiah', 1)
# (u'Bayne, Alexander', 1)
# (u'Cooper, John Gilbert', 1)
# (u'Burrow, James', 1)
# (u'Thomson, James', 16)
# (u'Le Dran, Henri-Franc\u0327ois', 2)
# (u'Saltoun of Abernethy, Alexander Fraser', 1)
# (u'Norris, John', 1)
# (u'Walker, George', 1)
# (u'Scott, Sarah', 1)
# (u'Browne, Moses', 1)
# (u'Secker, Thomas', 1)
# (u'Wesley, Samuel', 5)
# (u'Keble, Joseph', 1)
# (u'Fenton, Elijah', 3)
# (u'Middleton, Patrick', 1)
# (u'Hutchinson, Thomas', 1)
# (u'Taylor, Henry', 3)
# (u'Holmes, John', 3)
# (u'Reeves, William', 8)
# (u'Hutchins, John', 2)
# (u'Jortin, John', 10)
# (u'Philo', 2)
# (u'Newton, Benjamin', 1)
# (u'Luc, J. A. de', 2)
# (u'Adair, Robert', 1)
# (u'Foote, Samuel', 1)
# (u'Kennicott, Benjamin', 2)
# (u'Edwards, Joseph', 4)
# (u'Perronet, Vincent', 5)
# (u'Lyttelton, George Lyttelton', 12)
# (u'Behn, Aphra', 1)
# (u'Pomfret, John', 2)
# (u'Crossinge, Richard', 2)
# (u'Moore, Thomas', 1)
# (u'Shadwell, Thomas', 1)
# (u'Fleetwood, Henry', 1)
# (u'Friend.', 1)
# (u'Plantavit de la Pause, Guillaume', 1)
# (u'Altieri, F.', 1)
# (u'Trueman, John.', 1)
# (u'Castlemaine, Roger Palmer', 1)
# (u'Trenchard, John', 1)
# (u'Lancaster, Peter', 1)
# (u'Gilbert, John', 1)
# (u'Hasledine, William', 3)
# (u'Buchan, David Erskine', 2)
# (u'Du Pin, Louis Ellies', 2)
# (u'Dorchester, Dudley Carleton', 1)
# (u'Bellinger, Francis', 1)
# (u'Howel, Laurence', 1)
# (u'Caesar, Julius.', 2)
# (u'Cassillis, Susan Kennedy', 1)
# (u'Parker, Matthew', 2)
# (u'Read, James', 1)
# (u'Uzta\u0301riz, Gero\u0301nimo de', 1)
# (u'Markham, William', 1)
# (u'Story, Joseph', 2)
# (u'Arnall, William', 8)
# (u'Bernard, Francis', 4)
# (u'Tasso, Torquato', 2)
# (u'Blomer, Ralph', 1)
# (u'Gentleman of the Middle Temple.', 1)
# (u'Macclesfield, Thomas Parker', 1)
# (u'Crofts, Herbert', 1)
# (u'Holland, Richard', 2)
# (u'Deakin, William', 1)
# (u'Mackilligan, Daniel.', 1)
# (u'Some Oxford Electors.', 1)
# (u'Dennis, John', 3)
# (u'Whiston, John', 6)
# (u'Onely, Richard', 1)
# (u'Theocritus.', 1)
# (u'Mill, Alexander.', 1)
# (u'Congreve, William', 1)
# (u'Allen, John', 4)
# (u'Strange, John', 3)
# (u'Hume, David', 2)
# (u'Lavington, George', 1)
# (u'Feijo\u0301o y Montenegro, Benito Jero\u0301nimo', 2)
# (u'Josephus, Flavius.', 5)
# (u'Douglass, William', 3)
# (u'Egmond van der Nijenburg, Johannes Aegidius van', 1)
# (u'Evelyn, John', 1)
# (u'Goldsmith, Oliver', 1)
# (u'Widmore, Richard', 2)
# (u'Towne, John', 5)
# (u'Strother, Edward', 1)
# (u'Carter, Francis', 3)
# (u'MacAulay, Alexander', 1)
# (u'Settle, Elkanah', 1)
# (u'Taylor, John', 5)
# (u'Battie, William', 1)
# (u'Hickes, George', 9)
# (u'Bisse, Thomas', 21)
# (u'Watts, Isaac', 1)
# (u'Marshall, Nathaniel', 1)
# (u'Kirkland, Thomas', 1)
# (u'Sanchoniathon.', 1)
# (u'Alsop, Anthony', 2)
# (u'Hazeland, William', 4)
# (u'Lysias.', 2)
# (u'Randolph, Thomas', 2)
# (u'Shaw, Thomas', 1)
# (u'Lovat, Simon Fraser', 1)
# (u'St. Clair, James', 1)
# (u'Murrey, Robert', 1)
# (u'Boval, Frances.', 1)
# (u'Castell, Robert.', 2)
# (u'Maximus', 1)
# (u'Davis, Henry', 2)
# (u'Glaseour, Thomas.', 1)
# (u'H. C.', 1)
# (u'Kennett, White', 5)
# (u'Riccoboni, Marie Jeanne de Heurles Laboras de Mezie\u0300res', 5)
# (u'G. O.', 1)
# (u'Costa, Uriel', 1)
# (u'Jacob, Hildebrand', 10)
# (u'Lawson, John', 1)
# (u'Racine, Jean', 1)
# (u'Ecton, John', 6)
# (u'Cicero, Marcus Tullius.', 13)
# (u'Adams, William', 1)
# (u'Combe, Charles', 1)
# (u'Wales, William', 1)
# (u'Trusler, John', 1)
# (u'Jones, W.', 1)
# (u'Cochran, Thomas.', 1)
# (u'Anderson, William', 1)
# (u'Bacon, Francis', 4)
# (u'Hall-Stevenson, John', 1)
# (u'Astruc, John.', 1)
# (u'Reynolds, Richard', 1)
# (u'Macdonald, James', 1)
# (u'Montesquieu, Charles de Secondat', 3)
# (u'Barton, Philip', 1)
# (u'Purry, Jean Pierre', 1)
# (u'Orlebar, John.', 1)
# (u'Londinensis', 1)
# (u'Pomet, Pierre', 3)
# (u'Ronayne, Thomas.', 1)
# (u'Freind, John', 5)
# (u'Stirling, John', 2)
# (u'Clement, Aurelius.', 1)
# (u'Blair, Hamilton.', 1)
# (u'Maskelyne, Nevil', 8)
# (u'Annandale, George Van den Bempde\u0301', 1)
# (u'Burton, John', 5)
# (u'Nisbett, William', 2)
# (u'Martial.', 1)
# (u'Bernard, Jacques', 1)
# (u'Raspe, Rudolf Erich', 1)
# (u'Watson, Richard', 5)
# (u'Innes, Alexander', 1)
# (u'Home, John', 2)
# (u'Edwards, Thomas', 5)
# (u'Highmore, Joseph', 1)
# (u'Cox, Thomas', 1)
# (u'Bayes, Thomas', 1)
# (u'Butler, William', 1)
# (u"D'Urfey, Thomas", 1)
# (u'Lawrence, Thomas', 1)
# (u'Place, Conyers', 1)
# (u'Bate, George', 1)
# (u'Long, Roger', 2)
# (u'Van der Doort, Abraham', 1)
# (u'Booth, George', 2)
# (u'Person Who Had Been a Slave There.', 1)
# (u'Rapin, Rene\u0301', 2)
# (u'Theophrastus.', 1)
# (u'Anacreon.', 3)
# (u'Reid, Andrew', 1)
# (u'Wheatly, Charles', 1)
# (u'Johnson, Thomas', 1)
# (u'Smith, James', 1)
# (u'Barrow, Isaac', 3)
# (u'Hewerdine, Thomas', 1)
# (u'Berkeley, George', 11)
# (u'Juncker, Johann', 1)
# (u'Windham, William', 1)
# (u'Hale, Richard', 1)
# (u'Towers, Joseph', 1)
# (u'Anstey, Christopher', 1)
# (u'Wotton, William', 9)
# (u'Shadwell, Charles', 1)
# (u'Latham, John', 1)
# (u'Hoadly, Benjamin', 7)
# (u'Munro, George', 1)
# (u'Justinian', 1)
# (u'Murray, John', 1)
# (u'Pope, Alexander', 45)
# (u'Gratian, Theodorus.', 1)
# (u'Defoe, Daniel', 4)
# (u'Dawson, John', 3)
# (u'Davila, Arrigo Caterino', 2)
# (u'Marana, Giovanni Paolo', 7)
# (u'Swift, Thomas', 1)
# (u'Sacheverell, Henry', 10)
# (u'Wesley, John', 11)
# (u'Peyton, Edward', 1)
# (u'Hayes, W.', 1)
# (u'Henley, William', 4)
# (u'Morton, Charles', 1)
# (u'MacCulloch, Christian.', 1)
# (u'Mendes da Costa, Emanuel', 3)
# (u'Baker, Richard', 2)
# (u'Bridges', 1)
# (u'Bentley, Richard', 2)
# (u'Pennington, W.', 1)
# (u'Frank, Thomas.', 1)
# (u'Walls, George', 1)
# (u'Ibbetson, James', 2)
# (u'Brown, Peter', 1)
# (u'Balguy, Thomas', 1)
# (u'Ramsay, Allan', 1)
# (u'Wintringham, Clifton', 1)
# (u'Pearson, John', 5)
# (u'Barnes, William George', 1)
# (u'Chatterton, Thomas', 4)
# (u'Brett, Thomas', 3)
# (u'Busby, John', 1)
# (u'Johnson, R.', 1)
# (u'Whiston, William', 16)
# (u'Isocrates.', 4)
# (u'Kennedy, John', 2)
# (u'Massinger, Philip', 2)
# (u'Collins, Arthur', 1)
# (u'Mason, John', 2)
# (u'Centlivre, Susanna', 2)
# (u'Sawyer, Edmund', 2)
# (u'[Chapone, Sarah]', 1)
# (u'Morabin, Jacques', 1)
# (u'Mann, Nicholas', 1)
# (u'Lover of humanity and a friend to learning.', 1)
# (u'Gordon, Alexander', 1)
# (u'Owen, Edward', 3)
# (u'Cooke, Robert', 1)
# (u'Beaumont, John', 1)
# (u'Smith, George', 5)
# (u'Cassie, Andrew.', 1)
# (u'Lover of Mankind.', 1)
# (u'Gray, Charles', 2)
# (u'Payne, Squier', 1)
# (u'Lennox, Charlotte', 2)
# (u'Boulton, Richard', 1)
# (u'Culm, Benjamin', 1)
# (u'Lay-Man.', 1)
# (u'Castelman, John', 1)
# (u'Williams, Moses', 2)
# (u"M'Mahon, Thomas O'Brien.", 1)
# (u'Pettingal, John', 2)
# (u'Member of the States-General in Holland.', 1)
# (u'Justin', 4)
# (u'Blair, Patrick', 1)
# (u'Bird, John', 2)
# (u'Hamilton, James', 1)
# (u'Adams, John', 1)
# (u'Nieuwentyt, Bernard', 1)
# (u'Hutchinson, Francis', 1)
# (u'Gyles, Fletcher', 16)
# (u'Bellers, Fettiplace', 1)
# (u'Phillips, Thomas', 1)
# (u'Glanville, John', 1)
# (u'Wagstaffe, William', 2)
# (u'Aretaeus', 1)
# (u'Wilmot, Edward', 1)
# (u'Spelman, Henry', 3)
# (u'Callender, Edward', 1)
# (u'Hawkyns, George', 2)
# (u'Blackwall, Anthony', 2)
# (u'Ward, Caesar.', 1)
# (u'Tencin, Claudine Alexandrine Gue\u0301rin de', 1)
# (u'Mackpherson, William.', 1)
# (u'Sterne, Laurence', 1)
# (u'Scot, John', 1)
# (u'Rucellai, Bernardo', 2)
# (u'Wynn, John', 1)
# (u'Rymer, Thomas', 3)
# (u'Mudge, John', 1)
# (u'Charron, Pierre', 1)
# (u'Hurd, Richard', 20)
# (u'Richardson, John', 2)
# (u'Aeschylus.', 1)
# (u'Lockman, John', 3)
# (u'Free, John', 1)
# (u'Roberti, Antonius', 1)
# (u'Hody, Humphrey', 1)
# (u'Barrington, Shute', 2)
# (u'Barrington, Daines', 7)
# (u'Avison, Charles', 1)
# (u'Prideaux, Humphrey', 3)
# (u'Turner, Thomas', 1)
# (u'Haswell, John.', 1)
# (u'Addison, Joseph', 1)
# (u'Baxter, William', 6)
# (u'P. K.', 1)
# (u'Wilcocks, Joseph', 1)
# (u'Herodotus.', 1)
# (u'Hayes, Charles', 1)
# (u'Terence.', 1)
# (u'Sprat, Thomas', 1)
# (u'Gentleman of Oxford.', 1)
# (u'Whitehead, William', 1)
# (u'Borlase, William', 1)
# (u'Layer, Christopher', 1)
# (u'Talbot, William', 1)
# (u'Tyrwhitt, Thomas', 1)
# (u'Bingham, Joseph', 1)
# (u'Cullen, William', 1)
# (u'Aesop.', 4)
# (u'Horne, Henry.', 1)
# (u'Palmer, Samuel', 1)
# (u'Maittaire, Michael', 8)
# (u'Ford, John', 1)
# (u'Quillet, Claude', 2)
# (u'Erskine, Thomas', 2)
# (u'Mastini, Antonio', 1)
# (u'Curtius Rufus, Quintus.', 1)
# (u'Twells, Leonard', 6)
# (u'Hardouin, Jean', 2)
# (u'Sheridan, Frances Chamberlaine', 2)
# (u'Swieten, Gerard', 1)
# (u'Hammond, Anthony', 1)
# (u'Epictetus.', 5)
# (u'Garrick, David', 3)
# (u'Cranz, David', 1)
# (u'Sclater, William', 1)
# (u'Smith, Richard', 1)
# (u'Jackson, Edward', 1)
# (u'Smalbroke, Richard', 1)
# (u'Francia, Moses.', 1)
# (u'Cyprian', 1)
# (u'Webb, Philip Carteret', 5)
# (u'English freeholder.', 1)
# (u'Mottley, John', 3)
# (u'Aislabie, John', 2)
# (u'Harvey, William', 1)
# (u'Watson, William', 5)
# (u'Warren, Henry', 2)
# (u'Wilkins, David', 3)
# (u'Allestree, Richard', 1)
# (u'Carte, Thomas', 4)
# (u'Hutchinson, John', 3)
# (u'Cooke, Thomas', 2)
# (u'Ranby, John', 1)
# (u'R--er, Ab-l.', 1)
# (u'Pringle, John', 3)
# (u'Arbuckle, James.', 1)
# (u'Dickinson, John', 2)
# (u'Layman of the Church of England.', 1)
# (u'Hamilton, William Gerard', 1)
# (u'Wicquefort, Abraham de', 3)
# (u'Thou, Jacques Auguste de', 3)
# (u'Orrery, John Boyle', 1)
# (u'Nichols, Elizabeth Eyton.', 1)
# (u'Campbell, Elizabeth', 1)
# (u'Skinner, Thomas', 2)
# (u'Birch, Thomas', 2)
# (u'Thompson, Charles', 2)
# (u'Brett, Nathaniel.', 1)
# (u'Browne, Patrick', 1)
# (u'Wells, Edward', 3)
# (u'Gibbs, James', 7)
# (u'Dibben, Thomas', 3)
# (u'Barker, Thomas', 1)
# (u'Dameto, Juan Bautista', 2)
# (u'Langford, E.', 3)
# (u'Gataker, Thomas', 1)
# (u'Jodrell, Richard Paul', 1)
# (u'Chesterfield, Philip Dormer Stanhope', 1)
# (u'Percy, Thomas', 2)
# (u'Davis, Charles', 1)
# (u'White, Thomas', 1)
# (u'Rogers, John', 5)
# (u'Vigor', 1)
# (u'Brown, Robert', 1)
# (u'Newcome, Susanna.', 2)
# (u'Perry, John', 1)
# (u'Richer, Henri', 2)
# (u'Thomas, Pascoe.', 1)
# (u'Po\u0308llnitz, Karl Ludwig', 2)
# (u'Philander.', 1)
# (u'Richardson, William', 1)
# (u'Bambridge, Thomas', 1)
# (u'Tillotson, John', 5)
# (u'Russell, Richard', 2)
# (u'Middleton, Conyers', 16)
# (u'Parsons, James', 1)
# (u'Walpole, Horatio Walpole', 2)
# (u'Cowper, Ashley', 2)
# (u'Arnald, Richard', 8)
# (u'Derham, W.', 3)
# (u'Clarke, William', 2)
# (u'Snape, Andrew', 1)
# (u'Savage, John', 1)
# (u'Le Sage, Alain Rene\u0301', 1)
# (u'Barker, Robert', 1)
# (u'Kennedy, Margaret', 1)
# (u'Burke, Edmund', 9)
# (u'Fife, William Duff', 1)
# (u'Shenstone, William', 4)
# (u'Chaucer, Geoffrey', 3)
# (u'Lupton, William', 9)
# (u'Chishull, Edmund', 6)
# (u'Kynnynmound, Hugh Murray.', 2)
# (u'Palairet, Elias', 1)
# (u'Ward, John', 1)
# (u'Persius.', 1)
# (u'Private person.', 1)
# (u'Plumptre, Charles', 1)
# (u'Myself.', 1)
# (u'Sharp, Thomas', 4)
# (u'Nugent, Robert Nugent', 2)
# (u'Boyer, Abel', 27)
# (u'Pitfour, James Ferguson', 1)
# (u'Deletanville, Thomas.', 2)
# (u'Ray, John', 1)
# (u'Hill, Richard', 1)
# (u'Ockley, Simon', 1)
# (u'Cowper, William', 2)
# (u'English gentleman.', 1)
# (u'Banks, Jonathan.', 1)
# (u'Barwick, Peter', 1)
# (u'Prior, Thomas', 4)
# (u'Clements, Henry', 1)
# (u'Fiddes, Richard', 8)
# (u'Prat, Samuel', 1)
# (u'Beckford, Thomas.', 1)
# (u'Fleury, Claude', 2)
# (u'Clayton, Thomas', 1)
# (u'Ward, Edward', 1)
# (u'Keeling, Bartholomew', 1)
# (u'Paterson, Thomas', 2)
# (u'Lates, David Francesco', 1)
# (u'Dodson, James', 1)
# (u'Erasmus, Desiderius', 2)
# (u'Stona, Thomas', 1)
# (u'Markland, Jeremiah', 3)
# (u'Littleton, Adam', 1)
# (u'Desroches de Parthenay, Jean-Baptiste', 1)
# (u'Rudd, Sayer', 2)
# (u'Sparke, Joseph', 1)
# (u'Waterland, Daniel', 8)
# (u'Murray, Alexander', 2)
# (u'Fortescue, John', 3)
# (u'Berriman, William', 3)
# (u'Middleton, John', 2)
# (u'Tyrtaeus.', 1)
# (u'Spencer, Richard', 1)
# (u'Wallace, Robert', 1)
# (u'Ross, Robert', 1)
# (u'Locke, John', 4)
# (u'Potter, John', 1)
# (u'Ives, John', 1)
# (u'Osborne, Thomas', 1)
# (u'Sherlock, William', 2)
# (u'St. John, Pawlet', 5)
# (u'Milles, Thomas', 1)
# (u'St. Amand, George.', 1)
# (u'Bordes de Bercheres, Pierre de.', 1)
# (u'Xenophon', 2)
# (u'Cowley, Abraham', 2)
# (u'Mackworth, Humphrey', 3)
# (u'Rock', 1)
# (u'Armstrong, John', 12)
# (u'Gough, Strickland', 1)
# (u'Robinson, Nicholas', 2)
# (u'Morant, Philip', 6)
# (u'Brown, John', 27)
# (u'Shaw, William', 1)
# (u'Moodie, Elizabeth.', 2)
# (u'Leng, John', 3)
# (u'Henry, Matthew', 3)
# (u'Lovat, Amelia Fraser', 1)
# (u'Marsden, Robert', 2)
# (u'Clagett, Nicholas', 2)
# (u'Daniel, Richard', 1)
# (u'Vertue, George', 3)
# (u'Stebbing, Henry', 16)
# (u'Walker, Samuel', 2)
# (u'Law, William', 3)
# (u'Bollan, William', 1)
# (u'Salmon, Thomas', 1)
# (u'Bulstrode, Richard', 1)
# (u'Synge, Edward', 99)
# (u'Wynne, John', 3)
# (u'Harley, Edward', 2)
# (u'Gyllenborg, Carl', 1)
# (u'Euclid.', 3)
# (u'Grabe, Joannes Ernestus', 2)
# (u'Hewson, William', 2)
# (u'Steele, Joshua.', 3)
# (u'Hart, Edward', 1)
# (u'Auckland, William Eden', 1)
# (u'Steele, Richard', 2)
# (u'Adams, George', 1)
# (u'Castiglione, Baldassare', 2)
# (u'Gray, Thomas', 1)
# (u'Menteith, Robert.', 3)
# (u'Norman, John', 3)
# (u'Anstruther, John', 1)
# (u'Pemberton, Henry', 1)
# (u'Le Neve, Isabella.', 1)
# (u'Strafford, Thomas Wentworth', 2)
# (u'Echard, Laurence', 2)
# (u'Cooper, William', 1)
# (u'Junius', 17)
# (u'Graham, George', 1)
# (u'Crispe, Henry.', 1)
# (u'Lady.', 2)
# (u'Bacon, Roger', 1)
# (u'Mangey, Thomas', 22)
# (u'Etherege, George', 1)
# (u'Voltaire', 17)
# (u'Chambaud, Lewis', 2)
# (u'[Ross, William', 1)
# (u'Jackson, John', 4)
# (u'Frere, George.', 1)
# (u'Ainsworth, Robert', 1)
# (u'Shepherd, R.', 2)
# (u'Pellet, Thomas.', 1)
# (u'North, George', 1)
# (u'Private Gentleman.', 1)
# (u'Spinckes, Nathaniel', 6)
# (u'Barham, Henry', 1)
# (u'Stephens, William', 2)
# (u'Lover of the light.', 1)
# (u'Burnet, Thomas', 2)
# (u'Hare, Francis', 4)
# (u'Saunders, Edmund', 1)
# (u'Trapp, Joseph', 2)
# (u'Allix, Pierre', 1)
# (u'Randolph, Herbert', 1)
# (u'Cramer, Johann Andreas', 2)
# (u'Culpepper, Nathanael', 27)
# (u'Grosvenor, B.', 1)
# (u'Carr, John', 2)
# (u'Stewart, George', 1)
# (u'Demosthenes.', 6)
# (u'Leigh, Francis', 1)
# (u'Santorio, Santorio', 1)
# (u'Fe\u0301nelon, Franc\u0327ois de Salignac de La Mothe-', 3)
# (u'Luckombe, Philip', 1)
# (u'Piers, Sarah', 1)
# (u'Estwick, Samuel', 2)
# (u'Harris, Samuel', 1)
# (u'Le Neve, John', 6)
# (u'De-La-Cour, James', 1)
# (u'Cumberland, Richard', 1)
# (u'Mack Clair, George.', 1)
# (u'Fracastoro, Girolamo', 2)
# (u'Cockburn, William', 1)
# (u'Ovid', 4)
# (u'Bate, James', 1)
# (u'Hooper, George', 2)
# (u'Sayer, Joseph.', 2)
# (u'Aristides, Aelius.', 3)
# (u'Bownas, Samuel', 1)
# (u'Woodward, John', 2)
# (u'Hamilton, Archibald', 1)
# (u'Turner, Edward', 1)
# (u'Annandale, Charlotte Johnston', 1)
# (u'Piazza, Girolamo Bartolomeo.', 1)
# (u'Squire, Samuel', 2)
# (u'Abercromby, Alexander', 1)
# (u'Bate, Julius', 1)
# (u'Swift, Jonathan', 68)
# (u'Petit, Pierre', 1)
# (u'Temple, William Johnston', 1)
# (u'Cotes, Roger', 1)
# (u'Wright, S.', 4)
# (u'Burgh, William', 1)
# (u'Bonwicke, Ambrose', 1)
# (u'Campbell, Archibald', 1)
# (u'Heron, Patrick', 2)
# (u'Pliny', 6)
# (u'Anson, George Anson', 13)
# (u'Zinzano.', 1)
# (u'Dalrymple, James', 1)
# (u'Bell, Thomas', 1)
# (u'Bullock, Richard', 1)
# (u'Willymott, William', 2)
# (u'Gordon, Lodovick.', 1)
# (u'Drake, James', 1)
# (u'Llwyd, Humphrey', 1)
# (u'Hunter, Robert', 1)
# (u'Ogilby, William', 1)
# (u'Hammond, Robert', 1)
# (u'Heister, Lorenz', 9)
# (u'Oldisworth, William', 1)
# (u'Wallis, John', 1)
# (u'Jones, William', 1)
# (u'Clarke, Samuel', 4)
# (u'Maud, John', 2)
# (u'Warner, Richard', 3)
# (u'Priestley, Joseph', 1)
# (u'Lommius, Jodocus', 1)
# (u'Peirce, James', 2)
# (u'Fawkes, Francis', 1)
# (u'Solander, Daniel Charles', 1)
# (u'Barclay, P.', 2)
# (u'Le Moine, Abraham', 2)
# (u'Sannazaro, Jacopo', 1)
# (u'Aelian', 1)
# (u'Scot, William', 1)
# (u'Guarna, Andrea.', 1)
# (u'Gomez', 1)
# (u'Maty, Matthew', 1)
# (u'Wauchope, James', 2)
# (u'Clarke, Edward', 1)
# (u'Bull, George', 4)
# (u'Lloyd, Robert', 1)
# (u'Hildrop, John', 3)
# (u'Browne, Peter', 1)
# (u'Blackmore, Richard', 2)
# (u'Kettilby, Mary.', 1)
# (u'Lowther, Robert.', 1)
# (u'Ducarel, Andrew Coltee', 1)
# (u'Hasselquist, Fredric', 1)
# (u'Salwey, John', 1)
# (u'Culpeper, Nicholas', 1)
# (u'Tassie, James', 1)
# (u'Johnson, Samuel', 3)
# (u'Raper, Matthew', 1)
# (u'Mason, Francis', 2)
# (u'Hallifax, Samuel', 1)
# (u'Napier, Peter', 1)
# (u'Lee, Francis', 1)
# (u'Heath, Robert', 2)
# (u'Young, Edward', 2)
# (u'Morris, Corbyn', 1)
# (u'Taswell, William', 3)
# (u'Sturmy, Daniel', 1)
# (u'Crewe, John', 1)
# (u'Virgil.', 1)
# (u'Evans, Evan', 1)
# (u'Albin, Eleazar', 1)
# (u'Morris, Joseph', 1)
# (u'Morell, Charles', 1)
# (u'Heylyn, Peter', 1)
# (u'Bourne, Vincent', 1)
# (u'Pegge, Samuel', 8)
# (u'Smith, Edmund', 3)
# (u'Douglas, Archibald Douglas', 1)
# (u'Hamilton, William', 4)
# (u'Marcus Aurelius', 2)
# (u'Gastrell, Francis', 9)
# (u'Hartley, Thomas', 2)
# (u'Schrevel, Cornelis', 4)
# (u'Derrick, Samuel', 1)
# (u'Harris, William', 2)
# (u'Salmon, Nicholas.', 1)
# (u'Wright, J.', 1)
# (u'Piles, Roger de', 1)
# (u'Hamilton, John', 2)
# (u'Moore, John', 1)
# (u'Keill, James', 1)
# (u'Caius, John', 1)
# (u'Brydges, Henry', 1)
# (u'Young, William', 1)
# (u'Shepheard, James', 1)
# (u'Veneroni', 1)
# (u'Clanricarde, Ulick de Burgh', 1)
# (u'Jenkin, Robert', 4)
# (u'Crevier, Jean Baptiste Louis', 1)
# (u'Smollet, George', 1)
# (u'La Rochefoucauld, Franc\u0327ois', 1)
# (u'Smalridge, George', 1)
# (u'Ogilby, John', 1)
# (u'Marriott, James', 1)
# (u'Sykes, Arthur Ashley', 1)
# (u'Taylor, Brook', 1)
# (u'Hodges, Moses', 1)
# (u'Somervile, William', 10)
# (u'Jones, Griffith', 3)
# (u'Vanie\u0300re, J.', 1)
# (u'Bowers, Thomas', 1)
# (u'Brooke, Henry', 3)
# (u'Wynne, John Huddlestone', 2)
# (u'H. B.', 1)
# (u'Felton, Henry', 1)
# (u'Noke, James.', 1)
# (u'Dodd, William', 1)
# (u'Davies, Thomas', 1)
# (u'Roper, Joseph', 2)
# (u'Chiffinch, William', 1)
# (u'Davidson, John', 1)
# (u'Forster, Edward', 1)
# (u'Astruc, John', 3)
# (u'Ozinde, J. B.', 1)
# (u'King, Peter King', 4)
# (u'Ferber, Johann Jakob', 1)
# (u'Burnet, Gilbert', 2)
# (u'Sharp, George', 1)
# (u'Clifton, Francis', 1)
# (u'Stafford, Arthur.', 1)
# (u'Webb, Daniel', 4)
# (u'Tunstall, James', 4)
# (u'Harris, John', 2)
# (u'Darcy', 1)
# (u'Dodsley, Robert', 3)
# (u'Cockburn, James', 1)
# (u'Long, Edward', 1)
# (u'Young, Arthur', 1)
# (u'Osbeck, Pehr', 1)
# (u'Kuster, Ludolf', 2)
# (u'Whaley, John', 2)
# (u'Fraser, Hugh', 1)
# (u'Moray, Charles Stuart', 2)
# (u'Bridges, John', 1)
# (u'Warner, Joseph', 2)
# (u'Robinson, Bryan', 1)
# (u'Chalmer, John.', 1)
# (u'Butler, Samuel', 4)
# (u'W. D.', 3)
# (u'Jago, Richard', 2)
# (u'Elphinston, James', 1)
# (u'Leeke, Robert', 2)
# (u'Law, Edmund', 1)
# (u'Walsh, John', 2)
# (u'C. P.', 2)
# (u'Rogers, Charles', 1)
# (u'Gordon, Patrick', 1)
# (u'Pardies, Ignace Gaston', 1)
# (u'Boswell, John', 3)
# (u'Willis, Browne', 7)
# (u'Martin, Thomas', 1)
# (u'Brooke, Frances', 7)
# (u"Gentleman of Gray's-Inn.", 1)
# (u'Madden, Samuel', 1)
# (u'Hampe, Johann Heinrich', 1)
# (u'Paterson, John', 1)
# (u'Grierson, Robert', 1)
# (u'Owen, Henry', 5)
# (u'Re\u0301gnier, Mathurin', 1)
# (u'Lancelot, Claude', 1)
# (u'Lucian', 1)
# (u'Rowe, Nicholas', 4)
# (u'Gally, Henry', 4)
# (u'Franc\u0327ois.', 1)
# (u'Millot', 1)
# (u'Maxwell, Alexander', 1)
# (u'Healde, Thomas', 1)
# (u'Turner, William', 3)
# (u'Leigh, Richard', 1)
# (u'Canning, Elizabeth', 1)
# (u'Butts, Robert', 1)
# (u'Frame\u0301ry, Nicolas E\u0301tienne', 1)
# (u'Nairne, Edward', 1)
# (u'Chambers, Ephraim', 5)
# (u'Perlin, E\u0301tienne.', 1)
# (u'Duck, Stephen', 1)
# (u'Feyens, Thomas', 1)
# (u'Abernethy, John', 1)
# (u'Ashburnham, William', 2)
# (u'Sharp, John', 4)
# (u'Costard, George', 1)
# (u'Buttonshaw, Thomas', 1)
# (u'Shakespeare, William', 11)
# (u'Gibson, Matthew', 1)
# (u'Philopoeus, Carolus.', 1)
# (u'Collier, Jeremy', 12)
# (u'Fitzstephen, William', 1)
# (u'Crowe, William', 1)
# (u'Norfolk, Edward Howard', 1)
# (u'Brownrigg, William', 1)
# (u'Hutton, Charles', 5)
# (u'Bradley, Richard', 3)
# (u'Hamilton, Elizabeth Hamilton', 1)
# (u'Howell, William', 1)
# (u'Hardwicke, Philip Yorke', 2)
# (u'Gordon, James', 1)
# (u'Whitaker, John', 5)
# (u'Baker, Thomas', 1)
# (u'Perronet, Edward', 1)
# (u'Sagean, Mathieu', 1)
# (u'Hooke, N.', 2)
# (u'Turpin, Richard', 3)
# (u'Milanese Gentleman.', 1)
# (u'La Mottraye, Aubry de', 2)
# (u'Hawys, John.', 1)
# (u'Dyche, Thomas', 1)
# (u'Maclaurin, Colin', 1)
# (u'Revesi Bruti, Ottavio.', 1)
# (u'Warren, Thomas', 2)
# (u'Hervey, John Hervey', 1)
# (u'Tindal, N.', 1)
# (u'Smith, Robert', 1)
# (u'Lover of truth.', 1)
# (u'Wilcox, John', 1)
# (u'Hippocrates.', 4)
# (u'Sallust', 3)
# (u'Statius, P. Papinius', 2)
# (u'Portal, Abraham', 3)
# (u'Ayton, Margaret', 1)
# (u'Gildon, Charles', 1)
# (u'Pearce, Zachary', 1)
# (u'Euripides.', 4)
# (u'Ashby, George', 1)
# (u'Hesiod.', 2)
# (u'Savage, Richard', 2)
# (u'Grant, Archibald', 1)
# (u'Foreign Minister Residing in Sweden.', 1)
# (u'Buckingham, George Villiers', 1)
# (u'Rose, George', 3)
# (u'Atkyns, Robert', 1)
# (u'Cole, William', 1)
# (u'Leslie, Charles', 4)
# (u'Cleland, John', 3)
# (u'Delany, Patrick', 2)
# (u'Clayton, Robert', 19)
# (u'Whalley, John', 3)
# (u'Andrewes, Lancelot', 1)
# (u'Leti, Gregorio', 1)
# (u'Astell, Mary', 1)
# (u'Cockman, Thomas', 1)
# (u'Spenser, Edmund', 2)
# (u'De Britaine, William.', 1)
# (u'Winstanley, William', 62)
# (u'Manningham, Richard', 2)
# (u'Douglas, John', 2)
# (u'Ferguson, James', 2)
# (u'Robins, Benjamin', 1)
# (u'Mead, Richard', 17)
# (u'Forster, Johann Reinhold', 3)
# (u'Skelton, Philip', 3)
# (u'Ellis, John', 3)
# (u'Stevens, J. N.', 1)
# (u'English merchant.', 1)
# (u'Pocock, Thomas.', 1)
# (u'Stanley, Thomas', 1)
# (u'Stukeley, William', 1)
# (u'Price, Richard', 3)
# (u'Trebeck, Andrew', 2)
# (u'Holdsworth, E.', 2)
# (u'Curteis, Thomas', 1)
# (u'White, James', 1)
# (u'Naude\u0301, Gabriel', 1)
# (u'Gough, Richard', 2)
# (u'Wodhull, Michael', 1)
# (u'Campbell, John', 5)
# (u'Baker, Samuel', 3)
# (u'Gilchrist, Ebenezer', 2)
# (u'Fauques, Marianne-Agne\u0300s Pillement', 1)
# (u'Mackenzie, Kenneth', 2)
# (u'Physician in Town.', 1)
# (u'Folkes, Martin', 5)
# (u'Ephraem', 1)
# (u'Mills, Henry', 1)
# (u'Knox, William', 1)
# (u'Parker, William', 5)
# (u'Thomas, Hugh', 1)
# (u'Ellys, Anthony', 3)
# (u'McDouall, Alexander', 1)
# (u'Lewis, R.', 1)
# (u'Yardley, Edward', 1)
# (u'Quevedo, Francisco de', 1)
# (u'Nichols, John', 3)
# (u'La Ble\u0301terie, Jean Philippe Rene\u0301 de.', 1)
# (u'Bos\u030ckovic\u0301, Rudjer Josip', 1)
# (u'Langbaine, Gerard', 1)
# (u'Fuller, Thomas', 3)
# (u'Warner, Ferdinando', 1)
# (u'Gay, John', 7)
# (u'Mandeville, John', 2)
# (u'Fuller, P.', 1)
# (u'Theed, Richard', 2)
# (u'Bowyer, Thomas', 1)
# (u'Phillips, Edward', 2)
# (u'Jonson, Ben', 1)
# (u'T. B.', 1)
# (u'Gracia\u0301n, Baltasar', 2)
# (u'Stuart, James', 2)
# (u'Blackrie, Alexander', 2)
# (u'Hill, Edward', 1)
# (u'Durand, David', 3)
# (u'Melmoth, William', 8)
# (u'Delaune, William', 1)
# (u'Kersey, John', 1)
# (u'Exton, John', 2)
# (u'Nicholls, Frank', 1)
# (u'Original subscriber to the infirmary in James-Street, Westminster.', 1)
# (u'Grey, Richard', 10)
# (u'Grosley, Pierre Jean', 1)
# (u'Charteris, Francis', 1)
# (u'Camden, William', 2)
# (u'Mac Clellan, Marjory', 1)
# (u'Yorke, James', 1)
# (u'Jennens, Charles', 1)
# (u'Cunningham, T.', 1)
# (u'Paterson, Thomas.', 1)
# (u'Hamilton, James Hamilton', 5)
# (u'Parry, Richard', 3)
# (u'Essex, James', 2)
# (u'Ulloa, Antonio de', 3)
# (u'Nixon, John', 1)
# (u'Hopton, Susannah', 1)
# (u'Field, Nathaniel', 1)
# (u'Wake, William', 6)
# (u'Landon, John', 1)
# (u'Akenside, Mark', 5)
# (u'Allardice, Jane.', 1)
# (u'Zinzendorf, Nicolaus Ludwig', 5)
# (u'Wood, Robert', 1)
# (u'Vanbrugh, John', 1)
# (u'Burchett, Josiah', 2)
# (u'Senhouse, Peter', 1)
# (u'Knowles, Gilbert', 1)
# (u'Balguy, John', 1)
# (u'Cooke, William', 4)
# (u'Herle, John.', 1)
# (u'Norden, Frederik Ludvig', 2)
# (u'Burgh, James', 6)
# (u'Boswell, James', 1)
# (u'Breadalbane, John Campbell', 1)
# (u'Anderson, Thomas', 1)
# (u'La Fare, Charles-Auguste', 1)
# (u'Elector of the Borough of Great-Yarmouth.', 1)
# (u'Knight, James', 1)
# (u'Burroughs, William', 2)
# (u'Ford, Randolph.', 1)
# (u'Perfect, William', 1)
# (u'Cordier, Mathurin', 1)
# (u'Bowyer, William', 8)
# (u'South, Robert', 8)
# (u'Baynard, Edward', 1)
# (u'Cock', 1)
# (u'Hopkins, Bertie.', 1)
# (u'Selden, John', 4)
# (u'Switzer, Stephen', 2)
# (u'Mallet, David', 2)
# (u'Broxholme, Noel', 1)
# (u'Horsley, John', 2)
# (u'Fauconberg, Thomas Belasyse', 1)
# (u'Jervis, William.', 1)
# (u'Gray, Esther', 1)
# (u'Jones, John', 1)
# (u'Thurloe, John', 1)
# (u'Stow, John', 1)
# (u'White, Stephen', 5)
# (u'Benson, William', 1)
# (u'Cheselden, William', 13)
# (u'Horace.', 14)
# (u'Clarke, Joseph', 2)
# (u'Keate, George', 10)
# (u'Berington, Simon', 1)
# (u'Newton, Isaac', 7)
# (u'Aristaenetus.', 1)
# (u'More\u0301ri, Louis', 1)
# (u'Calmet, Augustin', 1)
# (u'Bolingbroke, Henry St. John', 4)
# (u'Anton, Pasqual Joseph.', 1)
# (u'Stanhope, George', 17)

# %% [markdown]
# Working with the contents of a dictionary is somewhat similar to working with a list, but with some twists because of the more complex key,value structure. Rather than accessing entries in the dictionary by index number, we use the key.

# %%
from pymarc import MARCReader
with open('data/Bowyer_from_ESTC-full.mrc','r') as infile :
    reader = MARCReader(infile)
    authors = {}
    for record in reader :
        if record['100'] :
            author_name = record['100']['a'].rstrip(',')
            authors.setdefault(author_name,0)
            authors[author_name] += 1
    
    # Let's see how many distinct authors we found. Rather than using len() directly, as we could with a list, we
    # need to get the len() of the keys in the dictionary.
    print(len(authors.keys()))
    
    # We access a dictionary entry not with an index number, as we did with lists, but with the key.
    #print(authors['Pagett, Thomas Catesby'])

    # We can't iterate through a dictionary quite as directly as we iterate through a list.
    #for author, count in authors.iteritems() :
     #   print(author + ': ' + str(count))
        
    # Dictionaries are, by nature, unsorted, but we can sort them at the time we display them, if we really want to:
    #for author in sorted(authors) :
     #   print(author + ': ' + str(authors[author]))

# %% [markdown]
# ## Conclusions ##
#
# This notebook has touched on a lot of different techniques, but none of them in too much depth. It may, though, provide a starting point and reference for some of the things that can come up most commonly in working with bibliographic data in MARC format.
#
# Another notebook in this directory (03-Living vs dead authors printed by Wm Bowyer (Case Study).ipynb) uses many of these techniques (and a few others) to take on a practical question from start to finish: of the titles printed by William Bowyer, how many were written by living authors and how many by dead ones? The next notebook in this directory (02-Parsing MARCXML with Python.ipynb) offers a quick look at a different flavor of MARC data--MARCXML, or MARC expressed in XML.
